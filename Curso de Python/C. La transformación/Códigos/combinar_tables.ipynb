# %% [markdown]
# # Combinar tablas: concatenate - append - merge - join-

# %% [markdown]
# En la combinación de tablas veremos 4 aspectos
#
# - El concatenate: para uniones tanto verticales como horizontales de dos tablas---> https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# - El append  ---> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.append.html
# - El merge  --->  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
# - El join
#
#
# https://realpython.com/pandas-merge-join-and-concat/
# https://realpython.com/pandas-merge-join-and-concat/
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html
# https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/
# https://www.geeksforgeeks.org/how-to-combine-two-dataframe-in-python-pandas/
# https://www.w3schools.com/python/python_mysql_join.asp

# %% [markdown]
# La función Concat concatena marcos de datos a lo largo de filas o columnas. Podemos pensar en ello como apilar múltiples marcos de datos. Merge combina marcos de datos basados en valores en columnas compartidas. La función Merge ofrece más flexibilidad en comparación con la función Concat porque permite combinaciones basadas en una condición.

# %%
import pandas as pd
import numpy as np

# %%
# Importar los datos

import os
cwd = os.getcwd()
cwd
# Print the current working directory
print("Current working directory: {0}".format(cwd))


path = 'C:\\Users\\oscar\\Desktop\\GitHub\\Python\\Jupyter Notebook\\Data Manipulation\\Combinar Dataframes - join-merge-concatenate-append'
# Change the current working directory
os.chdir(path)
# Let's check the new directory 
print("Current working directory: {0}".format(os.getcwd()))

import pandas as pd

employee = pd.read_excel('testData.xlsx', sheet_name= 'employee')

employee.head(3)
# Out:
# Current working directory: c:\Users\oscar\Desktop\GitHub\Python\Jupyter Notebook\Data Manipulation\Combinar Dataframes - join-merge-concatenate-append
# Current working directory: c:\Users\oscar\Desktop\GitHub\Python\Jupyter Notebook\Data Manipulation\Combinar Dataframes - join-merge-concatenate-append
#    employee_id  transport_expense  distance  age  education  sons  pet gender  \
# 0            1                235        11   37          3     1    1      F
# 1            2                235        29   48          1     1    5      M
# 2            3                179        51   38          1     0    0      M
#
#    disciplinary_faults  transportation_method
# 0                    3  public_transportation
# 1                    4  public_transportation
# 2                    5                bicycle

# %% [markdown]
# ## 1. Concatenar dos tablas
#
# La concatenación es una operación que combina dos tablas en una sola. Las dos tablas se añaden simplemente la una a la otra. Es decir, los datos no cambian y la tabla resultante contiene el mismo número de registros que las dos tablas originales juntas.
#
# Por concatenar, hablamos de una unión, y yo diriía que puede ser tanto horizontal como vertiral.
#
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# https://www.dataquest.io/blog/pandas-concatenation-tutorial/
# https://www.digitalocean.com/community/tutorials/pandas-concat-examples

# %%
# Concatenating DataFrames 

# The concat() function in pandas is used to append either columns or rows from one DataFrame to another. 
# The concat() function does all the heavy lifting of performing concatenation operations along an 
# axis while performing optional set logic (union or intersection) of the indexes (if any) on the other axes.


# pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=True)
#
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# https://www.digitalocean.com/community/tutorials/pandas-concat-examples

import pandas as pd

# First DataFrame
df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})

df1
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI

# %%
# Second DataFrame
df2 = pd.DataFrame({'id': ['B05', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})

df2
# Out:
#     id Name
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL

# %%
frames = [df1, df2]
frames
# Out:
# [    id Name
#  0  A01  ABC
#  1  A02  PQR
#  2  A03  DEF
#  3  A04  GHI,
#      id Name
#  0  B05  XYZ
#  1  B06  TUV
#  2  B07  MNO
#  3  B08  JKL]

# %%
result = pd.concat(frames) # axis=0 ---> por default
result
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL

# %%
result = pd.concat(frames, axis=0)   # si axis=0 ---> concatenación vertical
result
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL

# %%
result = pd.concat(frames, axis=1) # si axis=0 ---> concatenación horizontal 
result
# Out:
#     id Name   id Name
# 0  A01  ABC  B05  XYZ
# 1  A02  PQR  B06  TUV
# 2  A03  DEF  B07  MNO
# 3  A04  GHI  B08  JKL

# %% [markdown]
# ###   El join en la unión de tablas, usando la función .concat(, join =)
#
# En Pandas, el join es usado dentro de la función .concat, y sirve para unir dentro de los criterrios de "inner" y "outer"
# inner: todo lo que sea comun
# outer: todo lo que esté afuera también

# %%
# Joining Data Frames, con ls

# When we concatenated our DataFrames we simply added them to each other i.e. stacked them either vertically or side by side. Another way to
# combine DataFrames is to use columns in each dataset that contain common values (a common unique id). Combining DataFrames using a common field 
# is called “joining”. The columns containing the common values are called “join key(s)”. Joining DataFrames in this way is often useful when one 
# DataFrame is a “lookup table” containing additional data that we want to include in the other.

# %%
df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})

df1
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI

# %%
df3 = pd.DataFrame({'City': ['MUMBAI', 'PUNE', 'MUMBAI', 'DELHI'],
                    'Age': ['12', '13', '14', '12']})
df3
# Out:
#      City Age
# 0  MUMBAI  12
# 1    PUNE  13
# 2  MUMBAI  14
# 3   DELHI  12

# %%
# the default behaviour is join='outer'
# inner join
  
result2 = pd.concat([df1, df3], axis=1, join='inner')
result2
# Out:
#     id Name    City Age
# 0  A01  ABC  MUMBAI  12
# 1  A02  PQR    PUNE  13
# 2  A03  DEF  MUMBAI  14
# 3  A04  GHI   DELHI  12

# %%
# the default behaviour is join='outer'
# inner join
  
result3 = pd.concat([df1, df3], axis=0, join='outer')
result3
# Out:
#     id Name    City  Age
# 0  A01  ABC     NaN  NaN
# 1  A02  PQR     NaN  NaN
# 2  A03  DEF     NaN  NaN
# 3  A04  GHI     NaN  NaN
# 0  NaN  NaN  MUMBAI   12
# 1  NaN  NaN    PUNE   13
# 2  NaN  NaN  MUMBAI   14
# 3  NaN  NaN   DELHI   12

# %%
# the default behaviour is join='outer'
# inner join
  
result4 = pd.concat([df1, df3], axis=0, join='inner')
result4
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 0, 1, 2, 3]

# %% [markdown]
# En este caso, queremos combinar o concatenar de forma vertical tablas solo con columnas parecidas, al no haber, solo vemos el ínidica... no habría nada.

# %%
# the default behaviour is join='outer'
# inner join
  
result4 = pd.concat([df1, df3], axis=1, join='inner') # Inner o outer, no tiene efecto alguno, cuando se tratata e combinar de forma horizontal, dado que todos los elemntos som diferentes.
result4
# Out:
#     id Name    City Age
# 0  A01  ABC  MUMBAI  12
# 1  A02  PQR    PUNE  13
# 2  A03  DEF  MUMBAI  14
# 3  A04  GHI   DELHI  12

# %%
# the default behaviour is join='outer'
# inner join
  
result4 = pd.concat([df1, df3], axis=1, join='outer' )
result4
# Out:
#     id Name    City Age
# 0  A01  ABC  MUMBAI  12
# 1  A02  PQR    PUNE  13
# 2  A03  DEF  MUMBAI  14
# 3  A04  GHI   DELHI  12

# %%
result2 = pd.concat([df1, df3], axis=1, join='outer')
result2
# Out:
#     id Name    City Age
# 0  A01  ABC  MUMBAI  12
# 1  A02  PQR    PUNE  13
# 2  A03  DEF  MUMBAI  14
# 3  A04  GHI   DELHI  12

# %% [markdown]
# En este caso, el join no tiene efecto alguno, porque no vemos lo cómun, y lo que está afuera, pero vemos los siguientes casos.

# %%
# Veamos el caso de teams, si es un V LOOK UP, debería de funcionar. 

employee = pd.read_excel('testData.xlsx', sheet_name= 'employee')
workday = pd.read_excel('testData.xlsx', sheet_name= 'workday')

# %%
workday.head(3)
# Out:
#    employee_id       date group_cause  month  day_of_week  absent  \
# 0            1 2021-01-01        None      1            5       0
# 1            2 2021-01-01     Group_2      1            5       1
# 2            3 2021-01-01        None      1            5       0
#
#    days_since_last_absence  weather  holiday
# 0                        0      4.1        1
# 1                       20      4.1        1
# 2                       12      4.1        1

# %%
employee.head(3)
# Out:
#    employee_id  transport_expense  distance  age  education  sons  pet gender  \
# 0            1                235        11   37          3     1    1      F
# 1            2                235        29   48          1     1    5      M
# 2            3                179        51   38          1     0    0      M
#
#    disciplinary_faults  transportation_method
# 0                    3  public_transportation
# 1                    4  public_transportation
# 2                    5                bicycle

# %%
workday.shape
# Out:
# (2160, 9)

# %%
employee.shape
# Out:
# (37, 10)

# %%
data_all = pd.concat([workday, employee], axis=1, join='inner')
data_all.head(3)
# Out:
#    employee_id       date group_cause  month  day_of_week  absent  \
# 0            1 2021-01-01        None      1            5       0
# 1            2 2021-01-01     Group_2      1            5       1
# 2            3 2021-01-01        None      1            5       0
#
#    days_since_last_absence  weather  holiday  employee_id  transport_expense  \
# 0                        0      4.1        1            1                235
# 1                       20      4.1        1            2                235
# 2                       12      4.1        1            3                179
#
#    distance  age  education  sons  pet gender  disciplinary_faults  \
# 0        11   37          3     1    1      F                    3
# 1        29   48          1     1    5      M                    4
# 2        51   38          1     0    0      M                    5
#
#    transportation_method
# 0  public_transportation
# 1  public_transportation
# 2                bicycle

# %%
data_all.shape
# Out:
# (37, 19)

# %%
data_all.head(50)
# Out:
#     employee_id       date group_cause  month  day_of_week  absent  \
# 0             1 2021-01-01        None      1            5       0
# 1             2 2021-01-01     Group_2      1            5       1
# 2             3 2021-01-01        None      1            5       0
# 3             4 2021-01-01        None      1            5       0
# 4             5 2021-01-01        None      1            5       0
# 5             6 2021-01-01     Group_2      1            5       1
# 6             7 2021-01-01     Group_3      1            5       1
# 7             8 2021-01-01        None      1            5       0
# 8             9 2021-01-01        None      1            5       0
# 9            10 2021-01-01        None      1            5       0
# 10           11 2021-01-01     Group_3      1            5       1
# 11           12 2021-01-01        None      1            5       0
# 12           13 2021-01-01        None      1            5       0
# ...

# %% [markdown]
# No estoy del todo seguro, pero el "inner" es una buena forma de hacer el look up

# %% [markdown]
# ## 3. El append

# %%
# Concatenating using append

# A useful shortcut to concat() is append() instance method on Series and DataFrame. These methods actually predated concat. 

# First DataFrame
df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})
  
# Second DataFrame
df2 = pd.DataFrame({'id': ['B05', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})
  
# append method
result3 = df1.append(df2)
result3
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_15088\314051701.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result3 = df1.append(df2)
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL

# %%
# append() may take multiple objects to concatenate.

# First DataFrame
df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})
  
# Second DataFrame
df2 = pd.DataFrame({'id': ['B05', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})
  
df3 = pd.DataFrame({'City': ['MUMBAI', 'PUNE', 'MUMBAI', 'DELHI'],
                    'Age': ['12', '13', '14', '12']})
  
# appending multiple DataFrame
result4 = df1.append([df2, df3])
result4
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_15088\3891858215.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result4 = df1.append([df2, df3])
#     id Name    City  Age
# 0  A01  ABC     NaN  NaN
# 1  A02  PQR     NaN  NaN
# 2  A03  DEF     NaN  NaN
# 3  A04  GHI     NaN  NaN
# 0  B05  XYZ     NaN  NaN
# 1  B06  TUV     NaN  NaN
# 2  B07  MNO     NaN  NaN
# 3  B08  JKL     NaN  NaN
# 0  NaN  NaN  MUMBAI   12
# 1  NaN  NaN    PUNE   13
# 2  NaN  NaN  MUMBAI   14
# 3  NaN  NaN   DELHI   12

# %%
# First DataFrame
df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})
  
# Second DataFrame
df2 = pd.DataFrame({'id': ['B05', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})
  
df3 = pd.DataFrame({'City': ['MUMBAI', 'PUNE', 'MUMBAI', 'DELHI'],
                    'Age': ['12', '13', '14', '12']})
  
# appending multiple DataFrame
result = df1.append([df2, df3])
display(result)
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_15088\2805855798.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = df1.append([df2, df3])
#     id Name    City  Age
# 0  A01  ABC     NaN  NaN
# 1  A02  PQR     NaN  NaN
# 2  A03  DEF     NaN  NaN
# 3  A04  GHI     NaN  NaN
# 0  B05  XYZ     NaN  NaN
# 1  B06  TUV     NaN  NaN
# 2  B07  MNO     NaN  NaN
# 3  B08  JKL     NaN  NaN
# 0  NaN  NaN  MUMBAI   12
# 1  NaN  NaN    PUNE   13
# 2  NaN  NaN  MUMBAI   14
# 3  NaN  NaN   DELHI   12

# %% [markdown]
# ## 3. El merge
#
#
#
# DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#
# La función pandas.merge nos permite realizar "joins" (o uniones) entre tablas. El merge se realizan sobre las columnas o sobre las filas. En el primer caso, las etiquetas de las filas son ignoradas. En cualquier otro caso (joins realizado entre etiquetas de filas, o entre etiquetas de filas y de columnas), las etiquetas de filas se mantienen.
#
# https://interactivechaos.com/es/manual/tutorial-de-pandas/dataframes-la-funcion-merge#:~:text=merge%20nos%20permite%20realizar%20%22joins,etiquetas%20de%20filas%20se%20mantienen.
# https://interactivechaos.com/es/manual/tutorial-de-pandas/dataframes-la-funcion-merge#:~:text=merge%20nos%20permite%20realizar%20%22joins,etiquetas%20de%20filas%20se%20mantienen.
# https://www.digitalocean.com/community/tutorials/pandas-merge-two-dataframe
# https://realpython.com/pandas-merge-join-and-concat/
# https://www.w3schools.com/python/pandas/ref_df_merge.asp

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})

df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
pd.merge(df1,df2)
# Out:
#   lkey  value rkey
# 0  foo      5  foo

# %%
df1.merge(df2)
# Out:
#   lkey  value rkey
# 0  foo      5  foo

# %%
df1.merge(df2, how='cross')
# Out:
#    lkey  value_x rkey  value_y
# 0   foo        1  foo        5
# 1   foo        1  bar        6
# 2   foo        1  baz        7
# 3   foo        1  foo        8
# 4   bar        2  foo        5
# 5   bar        2  bar        6
# 6   bar        2  baz        7
# 7   bar        2  foo        8
# 8   baz        3  foo        5
# 9   baz        3  bar        6
# 10  baz        3  baz        7
# 11  baz        3  foo        8
# 12  foo        5  foo        5
# 13  foo        5  bar        6
# 14  foo        5  baz        7
# 15  foo        5  foo        8

# %%
df1.merge(df2, how='inner')
# Out:
#   lkey  value rkey
# 0  foo      5  foo

# %%
df1.merge(df2, how='left')
# Out:
#   lkey  value rkey
# 0  foo      1  NaN
# 1  bar      2  NaN
# 2  baz      3  NaN
# 3  foo      5  foo

# %%
df1.merge(df2, how='right')
# Out:
#   lkey  value rkey
# 0  foo      5  foo
# 1  NaN      6  bar
# 2  NaN      7  baz
# 3  NaN      8  foo

# %%
df1.merge(df2, how='outer')
# Out:
#   lkey  value rkey
# 0  foo      1  NaN
# 1  bar      2  NaN
# 2  baz      3  NaN
# 3  foo      5  foo
# 4  NaN      6  bar
# 5  NaN      7  baz
# 6  NaN      8  foo

# %%
df1.merge(df2, how='outer')
# Out:
#   lkey  value rkey
# 0  foo      1  NaN
# 1  bar      2  NaN
# 2  baz      3  NaN
# 3  foo      5  foo
# 4  NaN      6  bar
# 5  NaN      7  baz
# 6  NaN      8  foo

# %% [markdown]
# Ejemplo del test

# %%
employee = pd.read_excel('testData.xlsx', sheet_name= 'employee')
workday = pd.read_excel('testData.xlsx', sheet_name= 'workday')

workday.shape
# Out:
# (2160, 9)

# %%
data_1 = pd.merge(workday,employee, on = "employee_id", how = 'left')
data_1.head(3)
# Out:
#    employee_id       date group_cause  month  day_of_week  absent  \
# 0            1 2021-01-01        None      1            5       0
# 1            2 2021-01-01     Group_2      1            5       1
# 2            3 2021-01-01        None      1            5       0
#
#    days_since_last_absence  weather  holiday  transport_expense  distance  \
# 0                        0      4.1        1                235        11
# 1                       20      4.1        1                235        29
# 2                       12      4.1        1                179        51
#
#    age  education  sons  pet gender  disciplinary_faults  \
# 0   37          3     1    1      F                    3
# 1   48          1     1    5      M                    4
# 2   38          1     0    0      M                    5
#
#    transportation_method
# 0  public_transportation
# 1  public_transportation
# 2                bicycle

# %%
data_1.shape
# Out:
# (2220, 18)

# %%
database = pd.merge(employee,workday,on= 'employee_id', how='right')
# database.head(40)
database.shape
# Out:
# (2220, 18)

# %%
d1 = {'Name': ['Pankaj', 'Meghna', 'Lisa'], 'Country': ['India', 'India', 'USA'], 'Role': ['CEO', 'CTO', 'CTO']}
df1 = pd.DataFrame(d1)
df1
# Out:
#      Name Country Role
# 0  Pankaj   India  CEO
# 1  Meghna   India  CTO
# 2    Lisa     USA  CTO

# %%
df2 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Pankaj', 'Anupam', 'Amit']})
df2
# Out:
#    ID    Name
# 0   1  Pankaj
# 1   2  Anupam
# 2   3    Amit

# %%
df_merged = df1.merge(df2)
df_merged
# Out:
#      Name Country Role  ID
# 0  Pankaj   India  CEO   1

# %%
print('Result Left Join:\n', df1.merge(df2, how='left'))
# Out:
# Result Left Join:
#       Name Country Role   ID
# 0  Pankaj   India  CEO  1.0
# 1  Meghna   India  CTO  NaN
# 2    Lisa     USA  CTO  NaN

# %%
print('Result Right Join:\n', df1.merge(df2, how='right'))
# Out:
# Result Right Join:
#       Name Country Role  ID
# 0  Pankaj   India  CEO   1
# 1  Anupam     NaN  NaN   2
# 2    Amit     NaN  NaN   3

# %%
print('Result Outer Join:\n', df1.merge(df2, how='outer'))
# Out:
# Result Outer Join:
#       Name Country Role   ID
# 0  Pankaj   India  CEO  1.0
# 1  Meghna   India  CTO  NaN
# 2    Lisa     USA  CTO  NaN
# 3  Anupam     NaN  NaN  2.0
# 4    Amit     NaN  NaN  3.0

# %% [markdown]
# ## 4. El join
#
# IMPORTANTE, se debe de poner los "lsuffix="_l", rsuffix="_r"," dentro de df.join(), para que funcione!
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html
# https://www.w3schools.com/python/pandas/ref_df_join.asp
# https://sparkbyexamples.com/pandas/pandas-join-two-dataframes/
#
# DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)
# dataframe.join(other, on, how, lsuffix, rsuffix, sort)

# %% [markdown]
# # pandas join two DataFrames by Index
# df3=df1.join(df2, lsuffix="_left", rsuffix="_right")
#
# # pandas.merge() by Column
# df3=pd.merge(df1,df2)
#
# # DataFrame.merge() by Column
# df3=df1.merge(df2)
#
# # Merge DataFrames by Column
# df3=pd.merge(df1,df2, on='Courses')
#
# # When column names are different
# df3=pd.merge(df1,df2, left_on='Courses', right_on='Courses')
#
# # By using concat()
# df3=pd.concat([df1,df2],axis=1,join='inner')

# %%
import pandas as pd

data1 = {
  "name": ["Sally", "Mary", "John"],
  "age": [50, 40, 30]
}

data2 = {
  "qualified": [True, False, False]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = df1.join(df2)
newdf
# Out:
#     name  age  qualified
# 0  Sally   50       True
# 1   Mary   40      False
# 2   John   30      False

# %%
# Create DataFrames
import pandas as pd
technologies = {
    'Courses':["Spark","PySpark","Python","pandas"],
    'Fee' :[20000,25000,22000,30000],
    'Duration':['30days','40days','35days','50days'],
              }
index_labels=['r1','r2','r3','r4']
df1 = pd.DataFrame(technologies,index=index_labels)

technologies2 = {
    'Courses':["Spark","Java","Python","Go"],
    'Discount':[2000,2300,1200,2000]
              }
index_labels2=['r1','r6','r3','r5']
df2 = pd.DataFrame(technologies2,index=index_labels2)

print(df1)
print(df2)
# Out:
#     Courses    Fee Duration
# r1    Spark  20000   30days
# r2  PySpark  25000   40days
# r3   Python  22000   35days
# r4   pandas  30000   50days
#    Courses  Discount
# r1   Spark      2000
# r6    Java      2300
# r3  Python      1200
# r5      Go      2000

# %%
# pandas join two DataFrames
df3=df1.join(df2, lsuffix="_left", rsuffix="_right")
print(df3)
# Out:
#    Courses_left    Fee Duration Courses_right  Discount
# r1        Spark  20000   30days         Spark    2000.0
# r2      PySpark  25000   40days           NaN       NaN
# r3       Python  22000   35days        Python    1200.0
# r4       pandas  30000   50days           NaN       NaN

# %%
workday = pd.read_excel('testData.xlsx', sheet_name= 'workday')
workday.shape
# Out:
# (2160, 9)

# %%
employee = pd.read_excel('testData.xlsx', sheet_name= 'employee')
workday = pd.read_excel('testData.xlsx', sheet_name= 'workday')

data_2 = workday.join(employee, lsuffix="_l", rsuffix="_r", on='employee_id' , how = "left")

data_2.shape
# Out:
# (2160, 19)

# %%
data_2
# Out:
#       employee_id_l       date group_cause  month  day_of_week  absent  \
# 0                 1 2021-01-01        None      1            5       0
# 1                 2 2021-01-01     Group_2      1            5       1
# 2                 3 2021-01-01        None      1            5       0
# 3                 4 2021-01-01        None      1            5       0
# 4                 5 2021-01-01        None      1            5       0
# ...             ...        ...         ...    ...          ...     ...
# 2155             32 2021-03-01     Group_1      3            1       1
# 2156             33 2021-03-01        None      3            1       0
# 2157             34 2021-03-01        None      3            1       0
# 2158             35 2021-03-01        None      3            1       0
# 2159             13 2021-03-01        None      3            1       0
#
#       days_since_last_absence  weather  holiday  employee_id_r  \
# ...
